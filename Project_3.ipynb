# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve, auc

import os
import time
import sys

# %%
df = pd.read_csv("Train data values.csv")

df2 = pd.read_csv("Train data targets or labels.csv")

# %%
df2.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %%
df.insert(0, "status_group", df2["status_group"], allow_duplicates = False)

# %%
df["bin_status"] = df.apply(lambda r: 1 if r.status_group > "functional" else 0 , axis=1)

# %%
df.head()
# Out:
#      status_group     id  amount_tsh date_recorded        funder  gps_height  \
# 0      functional  69572      6000.0    2011-03-14         Roman        1390
# 1      functional   8776         0.0    2013-03-06       Grumeti        1399
# 2      functional  34310        25.0    2013-02-25  Lottery Club         686
# 3  non functional  67743         0.0    2013-01-28        Unicef         263
# 4      functional  19728         0.0    2011-07-13   Action In A           0
#
#       installer  longitude   latitude              wpt_name    ...      \
# 0         Roman  34.938093  -9.856322                  none    ...
# 1       GRUMETI  34.698766  -2.147466              Zahanati    ...
# 2  World vision  37.460664  -3.821329           Kwa Mahundi    ...
# 3        UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu    ...
# 4       Artisan  31.130847  -1.825359               Shuleni    ...
#
#    water_quality quality_group      quantity quantity_group  \
# ...

# %%
y=df["bin_status"]

# %%
df.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#         num_private   region_code  district_code    population  \
# count  59400.000000  59400.000000   59400.000000  59400.000000
# mean       0.474141     15.297003       5.629747    179.909983
# std       12.236230     17.587406       9.633649    471.482176
# ...

# %%
df.dtypes
# Out:
# status_group              object
# id                         int64
# amount_tsh               float64
# date_recorded             object
# funder                    object
# gps_height                 int64
# installer                 object
# longitude                float64
# latitude                 float64
# wpt_name                  object
# num_private                int64
# basin                     object
# subvillage                object
# region                    object
# region_code                int64
# district_code              int64
# lga                       object
# ward                      object
# population                 int64
# public_meeting            object
# recorded_by               object
# scheme_management         object
# scheme_name               object
# permit                    object
# construction_year          int64
# extraction_type           object
# extraction_type_group     object
# extraction_type_class     object
# ...

# %%
len(df.columns)
# Out:
# 42

# %%
del df["num_private"]

# %%
del df["id"]

# %%
del df["wpt_name"]

# %%
del df["public_meeting"]

# %%
del df["recorded_by"]

# %%
del df["scheme_name"]

# %%
del df["extraction_type"]

# %%
del df["extraction_type_group"]

# %%
del df["management"]

# %%
del df["payment"]

# %%
del df["quality_group"]

# %%
del df["source"]

# %%
del df["waterpoint_type"]

# %%
del df["lga"]

# %%
del df["date_recorded"]

# %%
del df["region_code"]

# %%
del df["district_code"]

# %%
del df["quantity_group"]

# %%
del df["status_group"]

# %%
len(df.columns)
# Out:
# 23

# %%
df.columns
# Out:
# Index(['amount_tsh', 'funder', 'gps_height', 'installer', 'longitude',
#        'latitude', 'basin', 'subvillage', 'region', 'ward', 'population',
#        'scheme_management', 'permit', 'construction_year',
#        'extraction_type_class', 'management_group', 'payment_type',
#        'water_quality', 'quantity', 'source_type', 'source_class',
#        'waterpoint_type_group', 'bin_status'],
#       dtype='object')

# %%
df.columns.sort_values()
# Out:
# Index(['amount_tsh', 'basin', 'bin_status', 'construction_year',
#        'extraction_type_class', 'funder', 'gps_height', 'installer',
#        'latitude', 'longitude', 'management_group', 'payment_type', 'permit',
#        'population', 'quantity', 'region', 'scheme_management', 'source_class',
#        'source_type', 'subvillage', 'ward', 'water_quality',
#        'waterpoint_type_group'],
#       dtype='object')

# %%
[df.dtypes.sort_values()]
# Out:
# [bin_status                 int64
#  construction_year          int64
#  gps_height                 int64
#  population                 int64
#  latitude                 float64
#  amount_tsh               float64
#  longitude                float64
#  basin                     object
#  source_class              object
#  source_type               object
#  quantity                  object
#  water_quality             object
#  payment_type              object
#  management_group          object
#  extraction_type_class     object
#  permit                    object
#  waterpoint_type_group     object
#  installer                 object
#  ward                      object
#  region                    object
#  subvillage                object
#  funder                    object
#  scheme_management         object
#  dtype: object]

# %%
cat_cols=['source_class',             
'source_type',              
'quantity',                  
'water_quality',             
'payment_type',              
'management_group',          
'extraction_type_class',     
'scheme_management',  
'waterpoint_type_group',     
'ward',                      
'region',                    
'subvillage',                
'basin',                     
'installer',                 
'funder',                    
'permit',                    
'bin_status' ]

# %%
cat_pd=df[cat_cols]

# %%
for each in cat_cols:
    print(each,cat_pd[each].nunique())
# Out:
# source_class 3
# source_type 7
# quantity 5
# water_quality 8
# payment_type 7
# management_group 5
# extraction_type_class 7
# scheme_management 12
# waterpoint_type_group 6
# ward 2092
# region 21
# subvillage 19287
# basin 9
# installer 2145
# funder 1897
# permit 2
# bin_status 2

# %% [markdown]
# # gotta drop these or label encode
# * ward 2092
# * subvillage 19287
# * installer 2145
# * funder 1897

# %%
df.shape
# Out:
# (59400, 23)

# %%
features_to_use = [
    'amount_tsh', 'gps_height',
       'longitude', 'latitude', 'basin', 'region',
       'population', 'scheme_management', 'permit',
       'construction_year', 'extraction_type_class', 'management_group',
       'payment_type', 'water_quality', 'quantity', 'source_type',
       'source_class', 'waterpoint_type_group'
]

# %%
X = df[features_to_use]

# %%
y = df["bin_status"]

# %%
X.head()
# Out:
#    amount_tsh  gps_height  longitude   latitude                    basin  \
# 0      6000.0        1390  34.938093  -9.856322               Lake Nyasa
# 1         0.0        1399  34.698766  -2.147466            Lake Victoria
# 2        25.0         686  37.460664  -3.821329                  Pangani
# 3         0.0         263  38.486161 -11.155298  Ruvuma / Southern Coast
# 4         0.0           0  31.130847  -1.825359            Lake Victoria
#
#     region  population scheme_management permit  construction_year  \
# 0   Iringa         109               VWC  False               1999
# 1     Mara         280             Other   True               2010
# 2  Manyara         250               VWC   True               2009
# 3   Mtwara          58               VWC   True               1986
# 4   Kagera           0               NaN   True                  0
#
#   extraction_type_class management_group payment_type water_quality  \
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: bin_status, dtype: int64

# %%
X_encoded = pd.get_dummies(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((44550, 98), (14850, 98))

# %%
X_train.head()
# Out:
#        amount_tsh  gps_height  longitude      latitude  population  \
# 24947        20.0         330  38.123839 -6.087137e+00          80
# 22630         0.0           0   0.000000 -2.000000e-08           0
# 13789         0.0           0  33.312321 -2.814100e+00           0
# 15697         0.0        1542  34.783049 -4.842093e+00          23
# 22613         0.0         523  34.660944 -1.070733e+01           1
#
#        construction_year  basin_Internal  basin_Lake Nyasa  basin_Lake Rukwa  \
# 24947               1972               0                 0                 0
# 22630                  0               0                 0                 0
# 13789                  0               0                 0                 0
# 15697               2010               1                 0                 0
# 22613               2013               0                 1                 0
#
#        basin_Lake Tanganyika             ...               source_type_spring  \
# ...

# %%
sds = StandardScaler()
sds.fit(X_train)
X_train = sds.transform(X_train)
X_test = sds.transform(X_test)

# %%
RandomForestClassifier(n_estimators=100,max_leaf_nodes=12,max_depth=30)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=30, max_features='auto', max_leaf_nodes=12,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
t0 = time.time()
clf = RandomForestClassifier(n_estimators=60,n_jobs=12)
  
clf.fit(X_train, y_train)
t1 = time.time()
   
ypred = clf.predict(X_test)
scores = roc_auc_score(y_test, ypred)
    
print(f"Random Forest took {t1-t0} seconds to train and got a score of {scores}")
print()
print("And here are the top features: ")
c = X_encoded.columns 
for cfi in zip(c, clf.feature_importances_):
    print(cfi)
print()
# Out:
# Random Forest took 1.5350191593170166 seconds to train and got a score of 0.8078197003765483
#
# And here are the top features:
# ('amount_tsh', 0.03002392418478126)
# ('gps_height', 0.07664145658095617)
# ('longitude', 0.16072056446263924)
# ('latitude', 0.15763310775027048)
# ('population', 0.05266268129545824)
# ('construction_year', 0.060753450265881845)
# ('basin_Internal', 0.004893403687384717)
# ('basin_Lake Nyasa', 0.0038110333519065787)
# ('basin_Lake Rukwa', 0.0038094209883170445)
# ('basin_Lake Tanganyika', 0.003953663990236171)
# ('basin_Lake Victoria', 0.003878738630419606)
# ('basin_Pangani', 0.003048660084120809)
# ('basin_Rufiji', 0.0037036951332074263)
# ('basin_Ruvuma / Southern Coast', 0.003060860587954036)
# ('basin_Wami / Ruvu', 0.003347532750696452)
# ('region_Arusha', 0.0027126050982294618)
# ('region_Dar es Salaam', 0.0006458410595174205)
# ('region_Dodoma', 0.0016142415143666632)
# ('region_Iringa', 0.006021491999574731)
# ...

# %%
from sklearn.externals import joblib
filename = 'finalized_model.sav'
joblib.dump(clf, filename)
# Out:
# ['finalized_model.sav']

# %%
df_test = pd.read_csv("Test data.csv")
df_test.head()
# Out:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  50785         0.0    2013-02-04                    Dmdd        1996
# 1  51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2  17168         0.0    2013-02-01                     NaN        1567
# 3  45559         0.0    2013-01-22              Finn Water         267
# 4  49871       500.0    2013-03-27                  Bruder        1260
#
#     installer  longitude   latitude                 wpt_name  num_private  \
# 0        DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 1         DWE  36.656709  -3.309214                  Kimnyak            0
# 2         NaN  34.767863  -5.004344           Puma Secondary            0
# 3  FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 4      BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
#
#            ...          payment_type water_quality quality_group  \
# ...

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=["0", "1"]))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.85      0.83      8098
#           1       0.81      0.76      0.79      6752
#
# avg / total       0.81      0.81      0.81     14850
